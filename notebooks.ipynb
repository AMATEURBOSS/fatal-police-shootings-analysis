# %% [markdown]
# <a href="https://colab.research.google.com/github/AMATEURBOSS/fatal-police-shootings-analysis/blob/main/notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# load data

# %%
import pandas as pd

# Direct raw file links from your GitHub repo:
url_agencies = "https://raw.githubusercontent.com/AMATEURBOSS/fatal-police-shootings-analysis/refs/heads/main/data/fatal-police-shootings-agencies%20.csv"
url_data = "https://raw.githubusercontent.com/AMATEURBOSS/fatal-police-shootings-analysis/main/data/fatal-police-shootings-data.csv"

# Load the data
df = pd.read_csv(url_data)
agencies = pd.read_csv(url_agencies)

# Quick preview
df.head()
agencies.head()
# Out:
#      id                                 name          type state oricodes  \
# 0  3145    Abbeville County Sheriff's Office       sheriff    SC  SC00100
# 1  2576           Aberdeen Police Department  local_police    WA  WA01401
# 2  2114            Abilene Police Department  local_police    TX  TX22101
# 3  2088  Abington Township Police Department  local_police    PA  PA04601
# 4  3187       Acadia Parish Sheriff's Office       sheriff    LA  LA00100
#
#    total_shootings
# 0                1
# 1                1
# 2                8
# 3                1
# 4                1

# %%
agencies.head()
# Out:
#      id                                 name          type state oricodes  \
# 0  3145    Abbeville County Sheriff's Office       sheriff    SC  SC00100
# 1  2576           Aberdeen Police Department  local_police    WA  WA01401
# 2  2114            Abilene Police Department  local_police    TX  TX22101
# 3  2088  Abington Township Police Department  local_police    PA  PA04601
# 4  3187       Acadia Parish Sheriff's Office       sheriff    LA  LA00100
#
#    total_shootings
# 0                1
# 1                1
# 2                8
# 3                1
# 4                1
